# %% [markdown]
# # Available Open Datasets

# %% [markdown]
# In this section we will track an summarize open datasets that we have come across and we think are valuable and interesting.

# %% [markdown]
# ## [iSIP](https://www.ifap.pt/isip/ows/)
